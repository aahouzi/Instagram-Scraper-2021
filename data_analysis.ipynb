# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# %%
# Load the scraped dataset
df = pd.read_pickle("feed.pkl")
df.head()
# Out:
#                                          Content URL  ...                                              Video
# 0  {'2474235709924306120': 'https://scontent-mrs2...  ...                      {'2474235709924306120': True}
# 1  {'2461878444734381055': 'https://scontent-mrs2...  ...  {'2461878444734381055': False, '24618784447594...
# 2  {'2461214049313035970': 'https://scontent-mrs2...  ...                     {'2461214049313035970': False}
# 3  {'2460426645962745723': 'https://scontent-mrs2...  ...                      {'2460426645962745723': True}
# 4  {'2455354455254382026': 'https://scontent-mrs2...  ...                      {'2455354455254382026': True}
#
# [5 rows x 9 columns]

# %%
# First, let's visualize the most common words in nike's description.

stopwords = set(STOPWORDS)
words = ""
for descrip in df['Description']: 
    tokens = descrip.split()
    tokens = [token.lower() for token in tokens]
    words += " ".join(tokens)
  
# Create the WordCloud object
wordcloud = WordCloud(width = 800, height = 800, 
                      background_color ='white', 
                      stopwords = stopwords, 
                      min_font_size = 10).generate(words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
# Let's see how the number of likes correlate with the number of comments
sns.set_theme()
sns.lmplot(data=df, x="Number of comments", y="Number of likes")

# %%
# Let's filter for exple on publications having a multi content feed
df[df['Multi content'] == 1]['Content URL'].tolist()
# Out:
# [{'2461878444734381055': 'https://scontent-mrs2-2.cdninstagram.com/v/t51.2885-15/e35/p1080x1080/130161221_882375999200677_6283304907942268905_n.jpg?_nc_ht=scontent-mrs2-2.cdninstagram.com&_nc_cat=1&_nc_ohc=S7qFW7kOUm0AX9vbEwx&tp=1&oh=69ccb4309369033c5f9f8dfb1253b061&oe=6024419E',
#   '2461878444751147654': 'https://scontent-mrs2-2.cdninstagram.com/v/t51.2885-15/e35/p1080x1080/129367311_442697490078428_3597034216730640095_n.jpg?_nc_ht=scontent-mrs2-2.cdninstagram.com&_nc_cat=108&_nc_ohc=XS1lvIrk470AX9DTTOx&tp=1&oh=787b22660346dc641de0b0cf66583187&oe=60271103',
#   '2461878444759497136': 'https://scontent-mrs2-2.cdninstagram.com/v/t51.2885-15/e35/p1080x1080/130301003_1334795383537858_8703482644578905591_n.jpg?_nc_ht=scontent-mrs2-2.cdninstagram.com&_nc_cat=110&_nc_ohc=YZTUYT-l7ZsAX_rSX8p&tp=1&oh=c54685b8bd61cf7621e83c7e7cee8a3e&oe=6023FECD',
# ...
